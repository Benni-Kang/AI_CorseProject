# %%
import numpy as np
import pandas as pd
import folium
import math 
import os
import time
import copy
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("CaliforniaRoadNetwork_Edges.csv")
df2 = pd.read_csv("CaliforniaRoadNetwork_Nodes.csv")

# %%
df1
# Out:
#        EdgeID  StartNodeID  EndNodeID
# 0           0            0          1
# 1           1            0          6
# 2           2            1          2
# 3           3            2          3
# 4           4            3          4
# ...       ...          ...        ...
# 21688   21688        21042      21043
# 21689   21689        21043      21044
# 21690   21690        21044      21045
# 21691   21691        21044      21047
# 21692   21692        21045      21046
#
# [21693 rows x 3 columns]

# %%
df2
# Out:
#        NodeID   Longitude   Latitude
# 0           0 -121.904167  41.974556
# 1           1 -121.902153  41.974766
# 2           2 -121.896790  41.988075
# 3           3 -121.889603  41.998032
# 4           4 -121.886681  42.008739
# ...       ...         ...        ...
# 21043   21043 -117.042160  32.550213
# 21044   21044 -117.043533  32.546886
# 21045   21045 -117.055840  32.553497
# 21046   21046 -117.067970  32.562462
# 21047   21047 -117.035332  32.541302
#
# [21048 rows x 3 columns]

# %%
# import folium
# m = folium.Map(
#     location=[41.974556, -121.904167],
#     zoom_start=7.5
    
# )
# for i in range(len(df2)):
#         m.add_child(
#         folium.CircleMarker(
#               [df2["Latitude"][i],df2["Longitude"][i]],
#              radius=2, # define how big you want the circle markers to be
#             color='yellow',
#             fill=True,
#             fill_color='red',
#              fill_opacity=1.5
#      )
#     )
# m.add_child(folium.LatLngPopup())
# display(m)
# m.save('Position Visualization.html')

# %%
lon_var_lad =  df2.iloc[:,1:]
EuclideanDistance = lambda a,b: math.sqrt((a[0]-a[1])**2 + (b[0]-b[1])**2)

def apply_get_EuclideanDistance(row):
    node1_Lon,node1_Lat = lon_var_lad.values[int(row['StartNodeID'])]
    node2_Lon,node2_Lat = lon_var_lad.values[int(row['EndNodeID'])]
    return EuclideanDistance((node1_Lon,node2_Lon),(node1_Lat,node2_Lat))
df1["EuclideanDistance"] = df1.apply(lambda x: 10000*apply_get_EuclideanDistance(x), axis =1)

graph_search = {k:[] for k in range(len(lon_var_lad))}
for row in df1.iloc[:,1:].values:
    StartNodeID , EndNodeID, EuclideanDistance = row
    StartNodeID , EndNodeID = map(int, (StartNodeID , EndNodeID))
    graph_search[StartNodeID].append((EndNodeID,EuclideanDistance))
    graph_search[EndNodeID].append((StartNodeID,EuclideanDistance))

# %%
graph_search
# Out:
# {0: [(1, 20.249187637906573), (6, 59.52750372727481)],
#  1: [(0, 20.249187637906573), (2, 143.4891110851992)],
#  2: [(1, 143.4891110851992), (3, 122.79854152221105)],
#  3: [(2, 122.79854152221105), (4, 110.98555446539574)],
#  4: [(3, 110.98555446539574)],
#  5: [(6, 61.5654610964435), (7, 14.088977961527986), (8, 120.08607746115295)],
#  6: [(0, 59.52750372727481), (5, 61.5654610964435)],
#  7: [(5, 14.088977961527986), (265, 32.12454046352606)],
#  8: [(5, 120.08607746115295), (298, 53.81547175293727)],
#  9: [(10, 129.39780253163462),
#   (36, 186.94388516340186),
#   (37, 29.48078865975801)],
#  10: [(9, 129.39780253163462), (11, 132.38474421170483)],
#  550: [(549, 220.46809859924605), (551, 170.0900308659324)],
#  551: [(550, 170.0900308659324), (552, 280.544090296011)],
#  552: [(551, 280.544090296011), (553, 57.18297386463469)],
#  553: [(552, 57.18297386463469), (554, 50.71389553161468)],
#  554: [(553, 50.71389553161468), (555, 252.51468254359656)],
#  555: [(554, 252.51468254359656), (556, 161.58349080272464)],
#  556: [(555, 161.58349080272464), (557, 257.8883527806439)],
#  557: [(556, 257.8883527806439), (558, 102.50842940957027)],
#  558: [(557, 102.50842940957027), (559, 93.35121852443439)],
#  559: [(558, 93.35121852443439), (560, 200.63464606093441)],
#  560: [(559, 200.63464606093441),
#   (561, 207.20838231120553),
#   (590, 27.514392597433297)],
#  561: [(560, 207.20838231120553), (562, 84.43814363195601)],
#  562: [(561, 84.43814363195601), (563, 234.99643507919197)],
#  563: [(562, 234.99643507919197), (564, 342.6156998739263)],
#  564: [(563, 342.6156998739263), (565, 97.56879521648337)],
#  565: [(564, 97.56879521648337), (566, 186.3223607084388)],
#  566: [(565, 186.3223607084388), (567, 77.61560732224612)],
#  567: [(566, 77.61560732224612), (568, 161.41073136570077)],
#  568: [(567, 161.41073136570077), (569, 191.1249886853995)],
#  569: [(568, 191.1249886853995), (570, 170.31858442347993)],
#  570: [(569, 170.31858442347993), (571, 154.9111797126889)],
#  571: [(570, 154.9111797126889), (572, 323.56438524653663)],
#  572: [(571, 323.56438524653663), (573, 297.50394904933495)],
#  573: [(572, 297.50394904933495), (574, 173.79906242559412)],
#  574: [(573, 173.79906242559412), (575, 83.20961302649081)],
#  575: [(574, 83.20961302649081), (576, 115.23799937507663)],
#  576: [(575, 115.23799937507663), (577, 252.31928681732424)],
#  577: [(576, 252.31928681732424), (578, 6.563687987703026)],
#  578: [(577, 6.563687987703026), (579, 129.0350064905548)],
#  579: [(578, 129.0350064905548), (580, 138.05939337827576)],
#  580: [(579, 138.05939337827576), (581, 283.9664842900511)],
#  581: [(580, 283.9664842900511), (582, 428.8701705645887)],
#  582: [(581, 428.8701705645887), (583, 134.55676720235414)],
#  583: [(582, 134.55676720235414), (584, 177.02092192740773)],
#  584: [(583, 177.02092192740773), (585, 93.08121668730257)],
#  585: [(584, 93.08121668730257), (586, 94.17487138300514)],
#  586: [(585, 94.17487138300514), (587, 20.654299794483507)],
#  587: [(586, 20.654299794483507), (588, 188.69515759560886)],
#  588: [(587, 188.69515759560886), (589, 234.14618510662223)],
#  589: [(257, 50.19973107495263), (588, 234.14618510662223)],
#  590: [(560, 27.514392597433297), (591, 14.94913040964821)],
#  591: [(590, 14.94913040964821),
#   (861, 260.87519046472795),
#   (917, 166.69321431898223)],
#  592: [(593, 117.72126103642195),
#   (642, 36.1620090701855),
#   (1083, 209.3274002609047)],
#  593: [(592, 117.72126103642195), (594, 134.6592117161073)],
#  594: [(593, 134.6592117161073), (595, 45.18495878064473)],
#  595: [(594, 45.18495878064473), (596, 174.0272992953217)],
#  596: [(595, 174.0272992953217), (597, 66.74043152394137)],
#  597: [(596, 66.74043152394137), (598, 59.63469627646776)],
#  794: [(793, 40.17837851390245), (795, 203.71767939960932)],
#  795: [(794, 203.71767939960932), (796, 168.39913360821066)],
#  796: [(795, 168.39913360821066), (797, 164.6489067683102)],
#  797: [(796, 164.6489067683102), (798, 65.93423693351568)],
#  798: [(797, 65.93423693351568), (799, 108.74887815521944)],
#  799: [(798, 108.74887815521944), (800, 77.92096636976162)],
#  800: [(799, 77.92096636976162), (801, 124.71451439185817)],
#  801: [(800, 124.71451439185817), (802, 168.60008066425274)],
#  802: [(801, 168.60008066425274), (803, 101.80760924420196)],
#  803: [(802, 101.80760924420196), (804, 102.82462594146075)],
#  804: [(803, 102.82462594146075), (805, 47.09966560388202)],
#  805: [(804, 47.09966560388202), (806, 46.96626981136414)],
#  806: [(805, 46.96626981136414), (807, 83.18022000451765)],
#  807: [(806, 83.18022000451765), (808, 76.46628015018045)],
#  808: [(807, 76.46628015018045), (809, 218.63617747311923)],
#  809: [(808, 218.63617747311923), (810, 112.55960243343458)],
#  810: [(809, 112.55960243343458), (811, 383.16424807108046)],
#  811: [(810, 383.16424807108046), (812, 236.22927507010445)],
#  812: [(811, 236.22927507010445), (813, 223.11741931094164)],
#  813: [(812, 223.11741931094164), (814, 171.50758846171908)],
#  814: [(813, 171.50758846171908), (815, 11.931760138469587)],
#  815: [(814, 11.931760138469587), (816, 67.84057782763995)],
#  816: [(59, 160.85539406559997), (815, 67.84057782763995)],
#  817: [(522, 71.79437582436046), (818, 167.12460650650993)],
#  818: [(817, 167.12460650650993), (819, 642.5649073050758)],
#  819: [(818, 642.5649073050758), (820, 392.592896649964)],
#  820: [(819, 392.592896649964), (821, 81.11081062346717)],
#  821: [(820, 81.11081062346717),
#   (875, 39.206366829868855),
#   (1007, 47.289560158717045)],
#  822: [(674, 41.43537739659657), (823, 302.6244342415176)],
#  823: [(822, 302.6244342415176), (824, 289.67558578533743)],
#  824: [(823, 289.67558578533743), (825, 523.0024141434845)],
#  825: [(824, 523.0024141434845), (851, 40.27401271292534)],
#  826: [(827, 146.77527891308083),
#   (845, 91.6501265684459),
#   (901, 107.91154757490018)],
#  827: [(826, 146.77527891308083), (828, 231.07488677917328)],
#  828: [(827, 231.07488677917328), (829, 147.54105225322394)],
#  829: [(828, 147.54105225322394), (830, 194.3702904253373)],
#  830: [(829, 194.3702904253373), (831, 282.13107042644555)],
#  831: [(830, 282.13107042644555), (832, 146.01500505092838)],
#  832: [(831, 146.01500505092838), (833, 239.1401262856895)],
#  833: [(832, 239.1401262856895), (834, 19.302331465468054)],
#  834: [(833, 19.302331465468054), (835, 127.4838876093535)],
#  835: [(834, 127.4838876093535), (836, 619.8704659039727)],
#  836: [(835, 619.8704659039727), (837, 59.66604729668687)],
#  837: [(836, 59.66604729668687), (838, 159.1883664090853)],
#  838: [(837, 159.1883664090853), (839, 267.60332303609283)],
#  839: [(838, 267.60332303609283), (840, 80.50793066524905)],
#  840: [(839, 80.50793066524905), (841, 148.94553434060464)],
#  841: [(840, 148.94553434060464), (842, 267.83054288110566)],
#  842: [(841, 267.83054288110566), (843, 170.58569283508257)],
#  890: [(891, 247.20448903702916),
#   (912, 65.5726299610245),
#   (1213, 162.3663342566089)],
#  891: [(890, 247.20448903702916), (892, 152.60209697119953)],
#  892: [(891, 152.60209697119953), (893, 320.66105251499556)],
#  893: [(892, 320.66105251499556), (894, 625.9922793451483)],
#  894: [(893, 625.9922793451483), (895, 254.65395520209998)],
#  895: [(894, 254.65395520209998), (896, 8.10160477924522)],
#  896: [(895, 8.10160477924522), (897, 151.00702798217696)],
#  897: [(896, 151.00702798217696), (898, 121.82242199205494)],
#  898: [(897, 121.82242199205494), (899, 143.08328903113213)],
#  899: [(898, 143.08328903113213), (900, 256.1620770137983)],
#  900: [(899, 256.1620770137983), (901, 326.2465037360396)],
#  901: [(826, 107.91154757490018), (900, 326.2465037360396)],
#  902: [(480, 835.037529455973), (903, 258.2388222170007)],
#  903: [(902, 258.2388222170007), (904, 294.55436170597363)],
#  904: [(903, 294.55436170597363), (905, 180.8934387974918)],
#  905: [(904, 180.8934387974918), (906, 1368.0253840482817)],
#  906: [(905, 1368.0253840482817), (907, 73.56296078857424)],
#  907: [(906, 73.56296078857424), (908, 244.743700429633)],
#  908: [(907, 244.743700429633), (909, 151.56830440431042)],
#  909: [(908, 151.56830440431042), (910, 588.1805642827371)],
#  910: [(909, 588.1805642827371), (911, 206.84165948867954)],
#  911: [(910, 206.84165948867954), (912, 177.48039328326064)],
#  912: [(890, 65.5726299610245), (911, 177.48039328326064)],
#  913: [(880, 191.5476695237928),
#   (916, 151.68810764167253),
#   (1027, 210.18494261015917)],
#  914: [(874, 261.9250665743753), (915, 95.57416387275305)],
#  915: [(914, 95.57416387275305), (916, 212.43172103082836)],
#  916: [(913, 151.68810764167253), (915, 212.43172103082836)],
#  917: [(591, 166.69321431898223), (918, 196.46552496559107)],
#  918: [(917, 196.46552496559107), (919, 146.85107728575113)],
#  919: [(918, 146.85107728575113), (920, 170.894726952088)],
#  920: [(919, 170.894726952088), (921, 119.5490066875174)],
#  921: [(920, 119.5490066875174), (922, 85.62121816471299)],
#  922: [(921, 85.62121816471299), (923, 139.73531908580676)],
#  923: [(922, 139.73531908580676), (924, 71.57964305594095)],
#  924: [(923, 71.57964305594095), (925, 155.16366230508476)],
#  925: [(924, 155.16366230508476), (926, 71.97586609416484)],
#  926: [(925, 71.97586609416484), (927, 118.68189162641215)],
#  927: [(926, 118.68189162641215), (928, 213.0811997807322)],
#  928: [(927, 213.0811997807322), (929, 71.90136855447612)],
#  929: [(928, 71.90136855447612), (930, 232.80171498520158)],
#  930: [(929, 232.80171498520158), (931, 149.0048834769959)],
#  931: [(930, 149.0048834769959), (932, 248.86546807464308)],
#  932: [(931, 248.86546807464308),
#   (933, 119.84228719440495),
#   (962, 336.9453231608516)],
#  933: [(932, 119.84228719440495),
#   (939, 150.66875256673268),
#   (965, 229.5791741425658)],
#  934: [(867, 181.1694035979851), (935, 37.78713140748372)],
#  935: [(934, 37.78713140748372), (936, 104.6497247965344)],
#  936: [(935, 104.6497247965344), (937, 199.40619574124344)],
#  984: [(983, 70.14108353892775), (985, 164.31267997324323)],
#  985: [(984, 164.31267997324323), (986, 42.223411752226006)],
#  986: [(985, 42.223411752226006), (987, 212.52944196053159)],
#  987: [(986, 212.52944196053159), (988, 68.49943795385374)],
#  988: [(987, 68.49943795385374), (989, 222.09302217766822)],
#  989: [(988, 222.09302217766822), (990, 295.75514872939965)],
#  990: [(989, 295.75514872939965), (991, 207.6159016066836)],
#  991: [(990, 207.6159016066836), (992, 75.7567666946522)],
#  992: [(991, 75.7567666946522), (993, 78.50749008859644)],
#  993: [(992, 78.50749008859644), (994, 121.47195396461356)],
#  994: [(993, 121.47195396461356), (995, 37.496577177000454)],
#  995: [(994, 37.496577177000454), (996, 99.00298227831988)],
#  996: [(995, 99.00298227831988), (997, 189.30327546028636)],
#  997: [(996, 189.30327546028636), (998, 84.59103557701711)],
#  998: [(997, 84.59103557701711), (999, 127.01038146559307)],
#  999: [(998, 127.01038146559307), (1000, 112.90651442677013)],
#  ...}

# %% [markdown]
# # Q1
# ![avator](./200_Question/question1.png)

# %%
# print(bfs(graph_search, 0, 1894, verbose=False))
# print(bfs(graph_search, 4, 3115, verbose=False))
# print(bfs(graph_search, 18, 9186, verbose=False))
# print(bfs(graph_search, 25, 15061, verbose=False))
# print(bfs(graph_search, 33, 21040, verbose=False))

# %%
# print(bfs(graph_search, 0, 1, verbose=False))

# %% [markdown]
# # Q2
# ![avator](./200_Question/question2.png)

# %%
# 生成100对随机的点，并且将其保存下来。用共同的数据来测试这五个算法

# %% [markdown]
# ### 2.1 BFS

# %%
def bfs(graph_to_search, initial_state, goal_state):
    # this is a list of a list because we need to eventually return
    # the entire PATH from the initial state to the goal state. So,
    # each element in this list represents a path from the the initial
    # state to one frontier node. We use the first element in each path
    # to represent the cost.
    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []

    while len(frontiers) > 0:   # use while loop to iteratively perform search
        
        path = frontiers.pop(0)  # Get the first element in the list
        node = path[-1]  # Get the last node in this path
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            # check if we reached the goal state or not
            if next_node == goal_state:
                # goal_path = new_path[1:]
                goal_cost = new_path[0]
                return  goal_cost,len(visited) # if yes, we can return this path and its cost
            else:
                frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)

# %% [markdown]
# ### 2.2 DFS

# %%
def dfs(graph_to_search, initial_state, goal_state):

    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []

    while len(frontiers) > 0:   # use while loop to iteratively perform search
        
        path = frontiers.pop(-1)  # Get the last element in the list
        node = path[-1]  # Get the last node in this path
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            # check if we reached the goal state or not
            if next_node == goal_state:
                # goal_path = new_path[1:]
                goal_cost = new_path[0]
                return  goal_cost,len(visited)  # if yes, we can return this path and its cost
            else:
                frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)

    return None

# %%
# test_start_node = data['start_node']
# test_end_node = data['end_node']
# Occupancy_of_space = 0
# p = [] #path
# c = [] #cost
# space = []
# for i in range(100):
#     p.append(i)
#     c.append(i)
#     space.append(i)
    

# time_start = time.perf_counter()
# for i in range(100):
#     (p[i],c[i],space[i]) = dfs(graph_search,test_start_node[i],test_end_node[i],verbose = False)
#     print('---',p[i],c[i],'\n\n\n')
    
# time_end = time.perf_counter()
# run_time = time_end - time_start
# print('Run_time:',run_time)

# for i in range(100):
#     Occupancy_of_space = Occupancy_of_space + space[i]
# print('Occupancy_of_space: ',Occupancy_of_space)

# %% [markdown]
# ### 2.3 UniformSearch

# %%
def uniform_cost_search(graph_to_search, initial_state, goal_state):
    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []

    while len(frontiers) > 0:   # use while loop to iteratively perform search
        
        frontiers = sorted(frontiers, key=lambda x: x[0])
        path = frontiers.pop(0)  # Get the first path in the queue
        node = path[-1]  # Get the last node in this path
        
        if node == goal_state:
            # goal_path = path[1:]
            goal_cost = path[0]
            return goal_cost,len(visited)
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)

    return None

# %%
# def fuction(search):
#     return str(search.name)

# fuction(uniform_cost_search)

# %%
# Occupancy_of_space = 0
# p = [] #path
# c = [] #cost
# space = []
# for i in range(100):
#     p.append(i)
#     c.append(i)
#     space.append(i)
    

# time_start = time.perf_counter()
# for i in range(100):
#     (p[i],c[i],space[i]) = uniform_cost_search(graph_search,test_start_node[i],test_end_node[i],verbose = False)
#     print('---',p[i],c[i],'\n\n\n')
    
# time_end = time.perf_counter()
# run_time = time_end - time_start
# print('Run_time:',run_time)

# for i in range(100):
#     Occupancy_of_space = Occupancy_of_space + space[i]
# print('Occupancy_of_space: ', Occupancy_of_space)

# %%
# x = ['BFS','DFS','Uniform cost search']
# time = [244.1602,214.4529,261.5256]
# space = [1060368,1093080,1079120]
# fig, ax1 = plt.subplots(figsize=(10, 10),dpi=100)



# ax1.bar(x=x, height = time,facecolor='b',width =0.7,edgecolor='white',zorder=1,alpha=0.3,label=u'Time')
# ax1.set_title("Performance Evaluation", fontsize=15)

# ax2 = ax1.twinx() 
# ax2.plot(x,space,color='r',linewidth = 2,marker='*',zorder=2,alpha=0.6,label=u'Memory')
# ax1.legend(loc=1)
# ax2.legend(loc=2)



# for i,(_x,_y) in enumerate(zip(x,time)):  
#     ax1.text(_x,_y+2,time[i],ha='center',color='black',fontsize=10)  #将数值显示在图形上

# for i,(_x,_y) in enumerate(zip(x,space)):  
#     ax2.text(_x,_y+3,space[i],color='black',fontsize=10)  #将数值显示在图形上

# # for x,y in zip(x,time):
# #     #ha horizontal alignment
# #     plt.text(x,y+0.05,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# # for x,y in zip(x,space):
# #     #ha horizontal alignment
# #     plt.text(x,y,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# # plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best')
# plt.grid()
# plt.savefig("coompare.jpg")
# plt.show()

# %%
# x = ['BFS','DFS','uniform_cost_search']

# fig, ax = plt.subplots(figsize=(7, 4))
# ax.bar(x=x, height = space)
# ax.set_title("Occupancy_of_space", fontsize=15)

# %%
'''
bfs,dfs,uniform search    -> len(visited)
tree like search -> len(frontiers)
greedy search -> len(visited)
A* Search -> len(visited)
depth limited dfs  -> len(visited)
Iterative limited -> len(frontiers)
'''

# %%
# heuristics function
def heuristics_function(start_node,end_node):
    node1_lon, node1_lat = lon_var_lad.values[start_node]
    node2_lon, node2_lat = lon_var_lad.values[end_node]
    return EuclideanDistance((node1_lon,node2_lon),(node1_lat,node2_lat))
    
def sld_to_des(des_node):
    graph_search_sld = {}
    nodes = list(range(len(lon_var_lad)))
    for node in nodes:
        graph_search_sld[node] = heuristics_function(node,des_node)
    return lambda x: graph_search_sld[x]

# %% [markdown]
# ### 2.4 GreedySearch

# %%
def greedy_search(graph_to_search, initial_state, goal_state,heuristic_fuc):

    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []
    times =0
    while len(frontiers) > 0:   # use while loop to iteratively perform search
        times+=1
        frontier_heuristics = []
        for x in frontiers:
            frontier_heuristics.append(heuristic_fuc[x[-1]])
        idx_to_pop = frontier_heuristics.index(min(frontier_heuristics))
        
        path = frontiers.pop(idx_to_pop)
        node = path[-1]  # Get the last node in this path
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            # check if we reached the goal state or not
            if next_node == goal_state:
                # goal_path = new_path[1:]
                goal_cost = new_path[0]
                print(times,goal_cost)
                return goal_cost,len(visited)  # if yes, we can return this path and its cost
            else:
                frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)

    return None

# %% [markdown]
# ### 2.5 A* Search

# %%
def a_star_search(graph_to_search, initial_state, goal_state,heuristic_fuc):
    
    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []

    while len(frontiers) > 0:   # use while loop to iteratively perform search
            
        # get the nodes in frontiers to be expanded
        estimated_path_cost = []
        for x in frontiers:
            heuristic_value = heuristic_fuc[x[-1]]
            path_cost = x[0]
            estimated_path_cost.append(heuristic_value+path_cost)
        idx_to_pop = estimated_path_cost.index(min(estimated_path_cost))
        
        path = frontiers.pop(idx_to_pop)
        node = path[-1]  # Get the last node in this path
        
        if node == goal_state:
            # goal_path = path[1:]
            goal_cost = path[0]
            return  goal_cost,len(visited)
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.

            frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)

    return None

# %% [markdown]
# # Q3
# ![avator](./200_Question/question3.png)

# %%
if 1==0: #sample 100 nodes
    start_node = []
    end_node = []

    for i in range(100):
        start_node.append(np.random.randint(0,len(df2))) 
        end_node.append( np.random.randint(0,len(df2)))
        
    data = {'start_node':start_node, 'end_node':end_node}
    data = pd.DataFrame(data)
    data.to_csv('test_data.csv',index = False)

# %%
test_data = pd.read_csv("test_data.csv")
test_start_node = test_data['start_node']
test_end_node = test_data['end_node']

# %%
def Validation(search,start_node,end_node,limited):
    test_times =len(start_node)
    space = [0]*test_times
    cost = [0]*test_times

    time_start = time.perf_counter()

    if limited == 0: # if fuction dose not has limited depth
        for i in range(test_times):
            cost[i], space[i] = search(graph_search,start_node[i],end_node[i])

    elif limited > 0: # if fuction has limited depth
        drop_time = 0
        for i in range(test_times):
            result = search(graph_search,start_node[i],end_node[i],limited)
            if result != None:
                cost[i-drop_time], space[i-drop_time] = result
            else:
                cost.pop(i-drop_time)
                space.pop(i-drop_time)
                drop_time+=1
                print(f"Cannot find goal for {drop_time} times in squence{i}")
    else:
        for i in range(test_times):
            cost[i], space[i] = search(graph_search,start_node[i],end_node[i],sld_to_des(end_node[i]))

    time_end = time.perf_counter()
    run_time = time_end - time_start
    print('Run_time:',run_time)

    print('Occupancy_of_space: ', np.mean(space))
    print()
    return np.mean(space) , run_time , np.mean(cost)

# %%
memory_dict=dict()
time_dict=dict()
cost_dict=dict()

# %%
memory_dict['BFS'],time_dict['BFS'],cost_dict['BFS'] = Validation(bfs,test_start_node,test_end_node,0)
memory_dict['DFS'],time_dict['DFS'],cost_dict['BFS'] = Validation(dfs,test_start_node,test_end_node,0)
memory_dict['Uniform_cost_search'],time_dict['Uniform_cost_search'],cost_dict['Uniform_cost_search'] = Validation(uniform_cost_search,test_start_node,test_end_node,0)
# Out:
# Run_time: 223.71027099999992
# Occupancy_of_space:  9479.78
#
# Run_time: 261.9542189999993
# Occupancy_of_space:  10123.3
#
# Run_time: 271.20924000000014
# Occupancy_of_space:  9368.67

# %%
memory_dict
# Out:
# {'BFS': 250.07255439999972,
#  'DFS': 289.2695654000004,
#  'Uniform_cost_search': 258.16829830000006}

# %%
memory_dict['Greedy_search'],time_dict['Greedy_search'],cost_dict['Greedy_search']  = Validation(greedy_search,test_start_node,test_end_node,-1)
memory_dict['A_star'],time_dict['A_star'],cost_dict['A_star']  = Validation(a_star_search,test_start_node,test_end_node,-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-1f92fe1fe58e> in <module>
# ----> 1 memory_dict['Greedy_search'],time_dict['Greedy_search'],cost_dict['Greedy_search']  = Validation(greedy_search,test_start_node,test_end_node,-1)
#       2 memory_dict['A_star'],time_dict['A_star'],cost_dict['A_star']  = Validation(a_star_search,test_start_node,test_end_node,-1)
#
# <ipython-input-58-7f882e86ba96> in Validation(search, start_node, end_node, limited)
#      23     else:
#      24         for i in range(test_times):
# ---> 25             cost[i], space[i] = search(graph_search,start_node[i],end_node[i],sld_to_des(end_node[i]))
#      26
#      27     time_end = time.perf_counter()
#
# <ipython-input-55-ebef64be6d27> in sld_to_des(des_node)
#       9     nodes = list(range(len(lon_var_lad)))
#      10     for node in nodes:
# ---> 11         graph_search_sld[node] = heuristics_function(node,des_node)
#      12     return lambda x: graph_search_sld[x]
#
# <ipython-input-55-ebef64be6d27> in heuristics_function(start_node, end_node)
#       3     node1_lon, node1_lat = lon_var_lad.values[start_node]
#       4     node2_lon, node2_lat = lon_var_lad.values[end_node]
# ----> 5     return EuclideanDistance((node1_lon,node2_lon),(node1_lat,node2_lat))
#       6
#       7 def sld_to_des(des_node):
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# # Q4
# ![avator](./200_Question/question4.png)

# %% [markdown]
# ### Depth Tree

# %%
### Depth TREE
def tree_like_search(graph_to_search, initial_state, goal_state):
    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []
    ver = 0 # to
    while len(frontiers) > 0:   # use while loop to iteratively perform search

        path = frontiers.pop(-1)  # Get the last element in the list
        node = path[-1]  # Get the last node in this path
        
        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        
        if len(actions) == 0:#If next actions is empty, then pass this node,discard visited nodes
            visited = copy.deepcopy(frontiers[-1])# Cover the old visited with the frontiers
            del visited[0]# delate the cost information
            del visited[-1]# delate the unvisited node
            continue
            
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            # check if we reached the goal state or not
            if next_node == goal_state:
                goal_path = new_path[1:]
                goal_cost = new_path[0]
                return goal_cost,len(goal_path)  # if yes, we can return this path and its cost
            else:
                frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)
        ver += 1
    return None

# %%
# for i in range(100):
#     start_node = np.random.randint(0,len(df2))
#     end_node = np.random.randint(0,len(df2))
#     print('---',dfs_tree(graph_search,start_node,end_node,verbose = False),'\n\n\n')

# %% [markdown]
# ### Depth limited

# %%
def Depth_Limited_Search(graph_to_search, initial_state, goal_state, limited_deepth):

    frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
    visited = []
    
    while len(frontiers) > 0:   # use while loop to iteratively perform search
        path = frontiers.pop(-1)  # Get the last element in the list
        node = path[-1]  # Get the last node in this path

        if len(path)-1 == limited_deepth: 
            continue

        if node in visited:  # check if we have expanded this node, if yes then skip this
            continue
            
        actions = graph_to_search[node] # get the possible actions
        for next_node, next_cost in actions:
            new_path = path.copy()
            new_path.append(next_node)
            new_path[0] = new_path[0] + next_cost
            
            if next_node in visited or new_path in frontiers:
                continue  # skip this node if it is already in the frontiers or the visited list.
            
            # check if we reached the goal state or not
            if next_node == goal_state:
                # goal_path = new_path[1:]
                goal_cost = new_path[0]
                return goal_cost , len(visited)  # if yes, we can return this path and its cost
            else:
                frontiers.append(new_path)  # add to the frontiers
        
        # after exploring all actions, we add this node to the visited list
        visited.append(node)
    return None

# %%
# Depth_Limited_Search(graph_search,0,1894,200,verbose = False)

# %% [markdown]
# ### Iterative_Deepening_dfs

# %%
def iterative_deepening_search_test2(graph_to_search, initial_state, goal_state):
    limited_deepth = 0
    now_deepth = -1

    while now_deepth < limited_deepth:
        frontiers = [[0, initial_state]]  # the frontier list only has the initial state, with a cost of 0.
        visited = []
        now_deepth += 1
        
        while len(frontiers) > 0:   # use while loop to iteratively perform search
            
            path = frontiers.pop(-1)  # Get the last element in the list
            node = path[-1]  # Get the last node in this path

            if len(path)-1 == limited_deepth: 
                continue

            if node in visited:  # check if we have expanded this node, if yes then skip this
                continue
                
            actions = graph_to_search[node] # get the possible actions
            for next_node, next_cost in actions:
                new_path = path.copy()
                new_path.append(next_node)
                new_path[0] = new_path[0] + next_cost
                
                if next_node in visited or new_path in frontiers:
                    continue  # skip this node if it is already in the frontiers or the visited list.
                
                # check if we reached the goal state or not
                if next_node == goal_state:
                    goal_path = new_path[1:]
                    goal_cost = new_path[0]
                    return goal_path, goal_cost,len(goal_path)  # if yes, we can return this path and its cost
                else:
                    frontiers.append(new_path)  # add to the frontiers
            
            # after exploring all actions, we add this node to the visited list
            visited.append(node)
        
        limited_deepth += 1
        now_deepth = -1
    return None

# %%
def iterative_Deepening_dfs(graph_to_search, initial_state, goal_state):
    limit = 0
    while True:
        frontiers = [[0, initial_state]]
        visited = []

        while len(frontiers) > 0:

            path = frontiers.pop(-1)
            node = path[-1]

            if len(path)-1 == limit:
                continue

            if node in visited:
                continue

            actions = graph_to_search[node]
            for next_node, next_cost in actions:
                new_path = path.copy()
                new_path.append(next_node)
                new_path[0] = new_path[0] + next_cost

                if next_node in visited or new_path in frontiers:
                    continue

                if next_node == goal_state:
                    goal_path = new_path[1:]
                    goal_cost = new_path[0]
                    return goal_cost,len(goal_path)
                else:
                    frontiers.append(new_path)

            visited.append(node)
        limit += 1

# %%
memory_dict['Tree_like_search'],time_dict['Tree_like_search'],cost_dict['Iterative_limited'] = Validation(tree_like_search,test_start_node,test_end_node,0)
# Out:
# Run_time: 253.25622269999985
# Occupancy_of_space:  2846.76

# %%
memory_dict['Iterative_limited'],time_dict['Iterative_limited'],cost_dict['Iterative_limited'] = Validation(iterative_Deepening_dfs,test_start_node,test_end_node,0)
# Out:
# Run_time: 251.6878044999994
# Occupancy_of_space:  46.20732422947936

# %%
memory_dict['Depth_limited'],time_dict['Depth_limited'],cost_dict['Depth_limited'] = Validation(Depth_Limited_Search,test_start_node,test_end_node,15000)
# Out:
# Run_time: 261.6451216000023
# Occupancy_of_space:  10123.3

# %%
def Comparison(memory_dict,time_dict):
    x = list(memory_dict.keys())
    time = list(time_dict.values())
    space = list(memory_dict.values())

    _, ax1 = plt.subplots(figsize=(10, 10),dpi=100)

    ax1.bar(x=x, height = time,facecolor='b',width =0.7,edgecolor='white',zorder=1,alpha=0.3,label=u'Time')
    ax1.set_title("Performance Evaluation", fontsize=15)

    ax2 = ax1.twinx() 
    ax2.plot(x,space,color='r',linewidth = 2,marker='*',zorder=2,alpha=0.6,label=u'Memory')
    ax1.legend(loc=1)
    ax2.legend(loc=2)

    for i,(_x,_y) in enumerate(zip(x,time)):  
        ax1.text(_x,_y+2,r'%.2f'%time[i],ha='center',color='black',fontsize=10)  #将数值显示在图形上

    for i,(_x,_y) in enumerate(zip(x,space)):  
        ax2.text(_x,_y-100,r'%.2f'%space[i],color='black',fontsize=10)  #将数值显示在图形上
    plt.grid()
    plt.savefig("coompare.jpg")
    plt.show()

Comparison(memory_dict,time_dict)
# for x,y in zip(x,time):
#     #ha horizontal alignment
#     plt.text(x,y+0.05,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# for x,y in zip(x,space):
#     #ha horizontal alignment
#     plt.text(x,y,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best')

# %%
# x = ['BFS','DFS','Uniform cost search']
# time = [244.1602,214.4529,261.5256]
# space = [1060368,1093080,1079120]
# fig, ax1 = plt.subplots(figsize=(10, 10),dpi=100)



# ax1.bar(x=x, height = time,facecolor='b',width =0.7,edgecolor='white',zorder=1,alpha=0.3,label=u'Time')
# ax1.set_title("Performance Evaluation", fontsize=15)

# ax2 = ax1.twinx() 
# ax2.plot(x,space,color='r',linewidth = 2,marker='*',zorder=2,alpha=0.6,label=u'Memory')
# ax1.legend(loc=1)
# ax2.legend(loc=2)



# for i,(_x,_y) in enumerate(zip(x,time)):  
#     ax1.text(_x,_y+2,time[i],ha='center',color='black',fontsize=10)  #将数值显示在图形上

# for i,(_x,_y) in enumerate(zip(x,space)):  
#     ax2.text(_x,_y+3,space[i],color='black',fontsize=10)  #将数值显示在图形上

# # for x,y in zip(x,time):
# #     #ha horizontal alignment
# #     plt.text(x,y+0.05,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# # for x,y in zip(x,space):
# #     #ha horizontal alignment
# #     plt.text(x,y,r'%.2f'%y,ha='center',va='bottom',fontsize=10)

# # plt.legend(handles=[l1,l2],labels=['aaa','bbb'],loc='best')
# plt.grid()
# plt.savefig("coompare.jpg")
# plt.show()
